# %% [markdown]
# # TAHAP 2 : **Program Untuk Menganalisa Dataset CSV**

# %% [markdown]
# Program ini menjalankan analisa pada kumpulan CSV yang merupakan hasil output proses ekstraksi data di program sebelumnya. Analisa ini bertujuan untuk menghitung nilai rata-rata dari jumlah frame sequence di setiap data CSV tersebut. Hasil analisa ini akan digunakan sebagai limit sequence yang bisa membantu proses training algoritma LSTM agar lebih konsisten dan akurat.

# %% [markdown]
# - Untuk menjalankan block program masing-masing, tekan *shift* + *enter* atau klik tombol icon '*Play*' ▶︎.
# - <b>JALANKAN SETIAP BLOK PROGRAM SECARA SEKUENSIAL!</b>
# - Konten di dalam program ini bisa digunakan sebagai panduan tutorial.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import defaultdict

# === CONFIG: change this if your CSV folder is different ===
csv_folder = Path("input/")

# Dictionary to store lengths per label
stats = defaultdict(list)
all_lengths = []

# Iterate through all CSV files
for csv_file in csv_folder.glob("*.csv"):
    name = csv_file.stem  # e.g., "Hello_003"
    
    # Extract label (everything before the last "_NNN")
    parts = name.split("_")
    if len(parts) < 2:
        # if filename doesn't follow label_idx pattern, skip or treat whole as label
        label = name
    else:
        label = "_".join(parts[:-1])  # supports multi-word labels

    df = pd.read_csv(csv_file)
    seq_length = len(df)

    stats[label].append(seq_length)
    all_lengths.append(seq_length)

# Convert to numpy array for global stats
all_lengths = np.array(all_lengths)

print("=== PER-LABEL STATISTICS ===\n")
for label, lengths in stats.items():
    lengths = np.array(lengths)
    print(f"Label: {label}")
    print(f"  Number of sequences  : {len(lengths)}")
    print(f"  Min sequence length  : {lengths.min()}")
    print(f"  Max sequence length  : {lengths.max()}")
    print(f"  Avg sequence length  : {lengths.mean():.2f}")
    print(f"  Median length        : {np.median(lengths):.2f}")
    print("")

print("=== GLOBAL SEQUENCE LENGTH DISTRIBUTION ===")
print(f"Total sequences        : {len(all_lengths)}")
print(f"Global min length      : {all_lengths.min()}")
print(f"Global max length      : {all_lengths.max()}")
print(f"Global mean length     : {all_lengths.mean():.2f}")
print(f"Global median length   : {np.median(all_lengths):.2f}")

# Key percentiles
p75 = np.percentile(all_lengths, 75)
p90 = np.percentile(all_lengths, 90)
p95 = np.percentile(all_lengths, 95)

print(f"75th percentile (P75)  : {p75:.2f}")
print(f"90th percentile (P90)  : {p90:.2f}")
print(f"95th percentile (P95)  : {p95:.2f}")

# === Auto-suggest padding length ===
# Heuristic: use P90 as a good trade-off, rounded up to nearest int
suggested_padding = int(np.ceil(p90))

print("\n=== SUGGESTED PADDING LENGTH ===")
print(f"Suggested padding length (≈P90): {suggested_padding}")

print("\nYou might choose:")
print(f"  - {int(np.ceil(p75))}  (P75)  → more truncation, faster training")
print(f"  - {suggested_padding} (P90)  → balanced")
print(f"  - {int(np.ceil(p95))} (P95)  → minimal truncation, more padding")
print(f"  - {int(all_lengths.max())} (max) → no truncation, lots of padding")
# Out:
# === PER-LABEL STATISTICS ===
#
# Label: 10
#   Number of sequences  : 220
#   Min sequence length  : 24
#   Max sequence length  : 110
#   Avg sequence length  : 61.66
#   Median length        : 68.00
#
# Label: 11
#   Number of sequences  : 180
#   Min sequence length  : 23
#   Max sequence length  : 99
#   Avg sequence length  : 57.01
#   Median length        : 62.50
#
# Label: 12
#   Number of sequences  : 180
#   Min sequence length  : 21
#   Max sequence length  : 90
#   Avg sequence length  : 55.55
#   Median length        : 59.50
#
# Label: 13
#   Number of sequences  : 180
#   Min sequence length  : 19
#   Max sequence length  : 107
#   Avg sequence length  : 54.57
#   Median length        : 57.00
#
# Label: 14
#   Number of sequences  : 180
#   Min sequence length  : 20
#   Max sequence length  : 91
#   Avg sequence length  : 55.92
#   Median length        : 58.00
#
# Label: 15
#   Number of sequences  : 180
#   Min sequence length  : 24
#   Max sequence length  : 100
#   Avg sequence length  : 57.29
#   Median length        : 60.00
#
# Label: 16
#   Number of sequences  : 180
#   Min sequence length  : 23
#   Max sequence length  : 88
#   Avg sequence length  : 54.77
#   Median length        : 57.00
#
# Label: 17
#   Number of sequences  : 180
#   Min sequence length  : 20
#   Max sequence length  : 102
#   Avg sequence length  : 55.43
#   Median length        : 57.00
#
# Label: 18
#   Number of sequences  : 180
#   Min sequence length  : 22
#   Max sequence length  : 97
#   Avg sequence length  : 56.27
#   Median length        : 59.00
#
# Label: 19
#   Number of sequences  : 180
#   Min sequence length  : 20
#   Max sequence length  : 99
#   Avg sequence length  : 58.57
#   Median length        : 61.00
#
# Label: 1
#   Number of sequences  : 220
#   Min sequence length  : 14
#   Max sequence length  : 101
#   Avg sequence length  : 48.72
#   Median length        : 55.50
#
# Label: 20
#   Number of sequences  : 220
#   Min sequence length  : 1
#   Max sequence length  : 98
#   Avg sequence length  : 58.24
#   Median length        : 62.50
#
# Label: 2
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 86
#   Avg sequence length  : 48.22
#   Median length        : 55.00
#
# Label: 30
#   Number of sequences  : 220
#   Min sequence length  : 20
#   Max sequence length  : 93
#   Avg sequence length  : 56.31
#   Median length        : 61.50
#
# Label: 3
#   Number of sequences  : 220
#   Min sequence length  : 10
#   Max sequence length  : 94
#   Avg sequence length  : 48.42
#   Median length        : 56.00
#
# Label: 40
#   Number of sequences  : 220
#   Min sequence length  : 20
#   Max sequence length  : 106
#   Avg sequence length  : 56.35
#   Median length        : 61.00
#
# Label: 4
#   Number of sequences  : 220
#   Min sequence length  : 12
#   Max sequence length  : 103
#   Avg sequence length  : 47.33
#   Median length        : 55.00
#
# Label: 50
#   Number of sequences  : 220
#   Min sequence length  : 25
#   Max sequence length  : 105
#   Avg sequence length  : 56.69
#   Median length        : 61.00
#
# Label: 5
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 95
#   Avg sequence length  : 48.48
#   Median length        : 57.00
#
# Label: 60
#   Number of sequences  : 220
#   Min sequence length  : 24
#   Max sequence length  : 91
#   Avg sequence length  : 57.12
#   Median length        : 61.00
#
# Label: 6
#   Number of sequences  : 220
#   Min sequence length  : 12
#   Max sequence length  : 104
#   Avg sequence length  : 47.96
#   Median length        : 55.00
#
# Label: 70
#   Number of sequences  : 220
#   Min sequence length  : 25
#   Max sequence length  : 101
#   Avg sequence length  : 57.63
#   Median length        : 60.00
#
# Label: 7
#   Number of sequences  : 220
#   Min sequence length  : 14
#   Max sequence length  : 107
#   Avg sequence length  : 48.44
#   Median length        : 54.00
#
# Label: 80
#   Number of sequences  : 220
#   Min sequence length  : 21
#   Max sequence length  : 100
#   Avg sequence length  : 58.64
#   Median length        : 63.00
#
# Label: 8
#   Number of sequences  : 220
#   Min sequence length  : 16
#   Max sequence length  : 100
#   Avg sequence length  : 52.51
#   Median length        : 58.50
#
# Label: 90
#   Number of sequences  : 220
#   Min sequence length  : 22
#   Max sequence length  : 106
#   Avg sequence length  : 59.55
#   Median length        : 62.00
#
# Label: 9
#   Number of sequences  : 220
#   Min sequence length  : 16
#   Max sequence length  : 122
#   Avg sequence length  : 53.51
#   Median length        : 57.00
#
# Label: adik
#   Number of sequences  : 15
#   Min sequence length  : 49
#   Max sequence length  : 61
#   Avg sequence length  : 55.33
#   Median length        : 56.00
#
# Label: adik_000
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: adik_001
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: adik_002
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: adik_003
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: adik_004
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: adik_005
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: adik_006
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: adik_007
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: adik_008
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: adik_009
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: adik_010
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: adik_011
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: adik_012
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: adik_013
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: adik_014
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: air
#   Number of sequences  : 16
#   Min sequence length  : 49
#   Max sequence length  : 89
#   Avg sequence length  : 71.31
#   Median length        : 72.50
#
# Label: air_000
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: air_001
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: air_002
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: air_003
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: air_004
#   Number of sequences  : 2
#   Min sequence length  : 71
#   Max sequence length  : 71
#   Avg sequence length  : 71.00
#   Median length        : 71.00
#
# Label: air_005
#   Number of sequences  : 2
#   Min sequence length  : 74
#   Max sequence length  : 74
#   Avg sequence length  : 74.00
#   Median length        : 74.00
#
# Label: air_006
#   Number of sequences  : 2
#   Min sequence length  : 69
#   Max sequence length  : 69
#   Avg sequence length  : 69.00
#   Median length        : 69.00
#
# Label: air_007
#   Number of sequences  : 2
#   Min sequence length  : 71
#   Max sequence length  : 71
#   Avg sequence length  : 71.00
#   Median length        : 71.00
#
# Label: air_008
#   Number of sequences  : 2
#   Min sequence length  : 78
#   Max sequence length  : 78
#   Avg sequence length  : 78.00
#   Median length        : 78.00
#
# Label: air_009
#   Number of sequences  : 2
#   Min sequence length  : 69
#   Max sequence length  : 69
#   Avg sequence length  : 69.00
#   Median length        : 69.00
#
# Label: air_010
#   Number of sequences  : 2
#   Min sequence length  : 79
#   Max sequence length  : 79
#   Avg sequence length  : 79.00
#   Median length        : 79.00
#
# Label: air_011
#   Number of sequences  : 2
#   Min sequence length  : 76
#   Max sequence length  : 76
#   Avg sequence length  : 76.00
#   Median length        : 76.00
#
# Label: air_012
#   Number of sequences  : 2
#   Min sequence length  : 89
#   Max sequence length  : 89
#   Avg sequence length  : 89.00
#   Median length        : 89.00
#
# Label: air_013
#   Number of sequences  : 2
#   Min sequence length  : 76
#   Max sequence length  : 76
#   Avg sequence length  : 76.00
#   Median length        : 76.00
#
# Label: air_014
#   Number of sequences  : 2
#   Min sequence length  : 79
#   Max sequence length  : 79
#   Avg sequence length  : 79.00
#   Median length        : 79.00
#
# Label: air_015
#   Number of sequences  : 2
#   Min sequence length  : 83
#   Max sequence length  : 83
#   Avg sequence length  : 83.00
#   Median length        : 83.00
#
# Label: aku
#   Number of sequences  : 20
#   Min sequence length  : 43
#   Max sequence length  : 66
#   Avg sequence length  : 53.75
#   Median length        : 54.00
#
# Label: aku_000
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: aku_001
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: aku_002
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: aku_003
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: aku_004
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: aku_005
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: aku_006
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: aku_007
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: aku_008
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: aku_009
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: aku_010
#   Number of sequences  : 2
#   Min sequence length  : 66
#   Max sequence length  : 66
#   Avg sequence length  : 66.00
#   Median length        : 66.00
#
# Label: aku_011
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: aku_012
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: aku_013
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: aku_014
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: aku_015
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: aku_016
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: aku_017
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: aku_018
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: aku_019
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: anda
#   Number of sequences  : 16
#   Min sequence length  : 46
#   Max sequence length  : 61
#   Avg sequence length  : 54.88
#   Median length        : 55.00
#
# Label: anda_000
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: anda_001
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: anda_002
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: anda_003
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: anda_004
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: anda_005
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: anda_006
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anda_007
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: anda_008
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: anda_009
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: anda_010
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: anda_011
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: anda_012
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: anda_013
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: anda_014
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: anda_015
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anjing
#   Number of sequences  : 12
#   Min sequence length  : 54
#   Max sequence length  : 64
#   Avg sequence length  : 57.83
#   Median length        : 58.00
#
# Label: anjing_000
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: anjing_001
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: anjing_002
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: anjing_003
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: anjing_004
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anjing_005
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anjing_006
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anjing_007
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: anjing_008
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: anjing_009
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: anjing_010
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: anjing_011
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: an
#   Number of sequences  : 220
#   Min sequence length  : 12
#   Max sequence length  : 81
#   Avg sequence length  : 43.26
#   Median length        : 49.00
#
# Label: awan
#   Number of sequences  : 10
#   Min sequence length  : 46
#   Max sequence length  : 63
#   Avg sequence length  : 53.10
#   Median length        : 54.00
#
# Label: awan_000
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: awan_001
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: awan_002
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: awan_003
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: awan_004
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: awan_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: awan_006
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: awan_007
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: awan_008
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: awan_009
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: ayah
#   Number of sequences  : 11
#   Min sequence length  : 48
#   Max sequence length  : 64
#   Avg sequence length  : 54.64
#   Median length        : 53.00
#
# Label: ayah_000
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: ayah_001
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: ayah_002
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: ayah_003
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: ayah_004
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: ayah_005
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: ayah_006
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: ayah_007
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: ayah_008
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: ayah_009
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: ayah_010
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: ayam
#   Number of sequences  : 9
#   Min sequence length  : 49
#   Max sequence length  : 76
#   Avg sequence length  : 61.67
#   Median length        : 61.00
#
# Label: ayam_000
#   Number of sequences  : 2
#   Min sequence length  : 69
#   Max sequence length  : 69
#   Avg sequence length  : 69.00
#   Median length        : 69.00
#
# Label: ayam_001
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: ayam_002
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: ayam_003
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: ayam_004
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: ayam_005
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: ayam_006
#   Number of sequences  : 2
#   Min sequence length  : 76
#   Max sequence length  : 76
#   Avg sequence length  : 76.00
#   Median length        : 76.00
#
# Label: ayam_007
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: ayam_008
#   Number of sequences  : 2
#   Min sequence length  : 71
#   Max sequence length  : 71
#   Avg sequence length  : 71.00
#   Median length        : 71.00
#
# Label: a
#   Number of sequences  : 220
#   Min sequence length  : 15
#   Max sequence length  : 98
#   Avg sequence length  : 54.10
#   Median length        : 52.00
#
# Label: baca
#   Number of sequences  : 10
#   Min sequence length  : 53
#   Max sequence length  : 64
#   Avg sequence length  : 59.30
#   Median length        : 61.00
#
# Label: baca_000
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: baca_001
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: baca_002
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: baca_003
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: baca_004
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: baca_005
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: baca_006
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: baca_007
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: baca_008
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: baca_009
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: bangun
#   Number of sequences  : 11
#   Min sequence length  : 34
#   Max sequence length  : 54
#   Avg sequence length  : 44.55
#   Median length        : 44.00
#
# Label: bangun_000
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: bangun_001
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: bangun_002
#   Number of sequences  : 2
#   Min sequence length  : 34
#   Max sequence length  : 34
#   Avg sequence length  : 34.00
#   Median length        : 34.00
#
# Label: bangun_003
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: bangun_004
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: bangun_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: bangun_006
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: bangun_007
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: bangun_008
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: bangun_009
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: bangun_010
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: baru
#   Number of sequences  : 11
#   Min sequence length  : 39
#   Max sequence length  : 51
#   Avg sequence length  : 46.45
#   Median length        : 48.00
#
# Label: baru_000
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: baru_001
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: baru_002
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: baru_003
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: baru_004
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: baru_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: baru_006
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: baru_007
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: baru_008
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: baru_009
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: baru_010
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: berat
#   Number of sequences  : 11
#   Min sequence length  : 41
#   Max sequence length  : 59
#   Avg sequence length  : 49.55
#   Median length        : 51.00
#
# Label: berat_000
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: berat_001
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: berat_002
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: berat_003
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: berat_004
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: berat_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: berat_006
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: berat_007
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: berat_008
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: berat_009
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: berat_010
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: ber
#   Number of sequences  : 220
#   Min sequence length  : 10
#   Max sequence length  : 102
#   Avg sequence length  : 45.90
#   Median length        : 54.00
#
# Label: besar
#   Number of sequences  : 12
#   Min sequence length  : 39
#   Max sequence length  : 61
#   Avg sequence length  : 48.75
#   Median length        : 48.00
#
# Label: besar_000
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: besar_001
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: besar_002
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: besar_003
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: besar_004
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: besar_005
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: besar_006
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: besar_007
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: besar_008
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: besar_009
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: besar_010
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: besar_011
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: burung
#   Number of sequences  : 11
#   Min sequence length  : 46
#   Max sequence length  : 66
#   Avg sequence length  : 55.73
#   Median length        : 56.00
#
# Label: burung_000
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: burung_001
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: burung_002
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: burung_003
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: burung_004
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: burung_005
#   Number of sequences  : 2
#   Min sequence length  : 66
#   Max sequence length  : 66
#   Avg sequence length  : 66.00
#   Median length        : 66.00
#
# Label: burung_006
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: burung_007
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: burung_008
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: burung_009
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: burung_010
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: b
#   Number of sequences  : 220
#   Min sequence length  : 16
#   Max sequence length  : 100
#   Avg sequence length  : 52.43
#   Median length        : 50.50
#
# Label: cepat
#   Number of sequences  : 11
#   Min sequence length  : 28
#   Max sequence length  : 44
#   Avg sequence length  : 35.45
#   Median length        : 34.00
#
# Label: cepat_000
#   Number of sequences  : 2
#   Min sequence length  : 36
#   Max sequence length  : 36
#   Avg sequence length  : 36.00
#   Median length        : 36.00
#
# Label: cepat_001
#   Number of sequences  : 2
#   Min sequence length  : 28
#   Max sequence length  : 28
#   Avg sequence length  : 28.00
#   Median length        : 28.00
#
# Label: cepat_002
#   Number of sequences  : 2
#   Min sequence length  : 33
#   Max sequence length  : 33
#   Avg sequence length  : 33.00
#   Median length        : 33.00
#
# Label: cepat_003
#   Number of sequences  : 2
#   Min sequence length  : 34
#   Max sequence length  : 34
#   Avg sequence length  : 34.00
#   Median length        : 34.00
#
# Label: cepat_004
#   Number of sequences  : 2
#   Min sequence length  : 34
#   Max sequence length  : 34
#   Avg sequence length  : 34.00
#   Median length        : 34.00
#
# Label: cepat_005
#   Number of sequences  : 2
#   Min sequence length  : 31
#   Max sequence length  : 31
#   Avg sequence length  : 31.00
#   Median length        : 31.00
#
# Label: cepat_006
#   Number of sequences  : 2
#   Min sequence length  : 31
#   Max sequence length  : 31
#   Avg sequence length  : 31.00
#   Median length        : 31.00
#
# Label: cepat_007
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: cepat_008
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: cepat_009
#   Number of sequences  : 2
#   Min sequence length  : 39
#   Max sequence length  : 39
#   Avg sequence length  : 39.00
#   Median length        : 39.00
#
# Label: cepat_010
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: cerah
#   Number of sequences  : 12
#   Min sequence length  : 38
#   Max sequence length  : 113
#   Avg sequence length  : 49.83
#   Median length        : 43.50
#
# Label: cerah_000
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: cerah_001
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: cerah_002
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: cerah_003
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: cerah_004
#   Number of sequences  : 2
#   Min sequence length  : 38
#   Max sequence length  : 38
#   Avg sequence length  : 38.00
#   Median length        : 38.00
#
# Label: cerah_005
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: cerah_006
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: cerah_007
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: cerah_008
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: cerah_009
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: cerah_010
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: cerah_011
#   Number of sequences  : 2
#   Min sequence length  : 113
#   Max sequence length  : 113
#   Avg sequence length  : 113.00
#   Median length        : 113.00
#
# Label: c
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 103
#   Avg sequence length  : 50.16
#   Median length        : 49.00
#
# Label: danau
#   Number of sequences  : 12
#   Min sequence length  : 49
#   Max sequence length  : 71
#   Avg sequence length  : 60.50
#   Median length        : 61.00
#
# Label: danau_000
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: danau_001
#   Number of sequences  : 2
#   Min sequence length  : 71
#   Max sequence length  : 71
#   Avg sequence length  : 71.00
#   Median length        : 71.00
#
# Label: danau_002
#   Number of sequences  : 2
#   Min sequence length  : 69
#   Max sequence length  : 69
#   Avg sequence length  : 69.00
#   Median length        : 69.00
#
# Label: danau_003
#   Number of sequences  : 2
#   Min sequence length  : 66
#   Max sequence length  : 66
#   Avg sequence length  : 66.00
#   Median length        : 66.00
#
# Label: danau_004
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: danau_005
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: danau_006
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: danau_007
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: danau_008
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: danau_009
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: danau_010
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: danau_011
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: dengan
#   Number of sequences  : 11
#   Min sequence length  : 44
#   Max sequence length  : 66
#   Avg sequence length  : 52.36
#   Median length        : 53.00
#
# Label: dengan_000
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: dengan_001
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: dengan_002
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: dengan_003
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: dengan_004
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: dengan_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: dengan_006
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: dengan_007
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: dengan_008
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: dengan_009
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: dengan_010
#   Number of sequences  : 2
#   Min sequence length  : 66
#   Max sequence length  : 66
#   Avg sequence length  : 66.00
#   Median length        : 66.00
#
# Label: di
#   Number of sequences  : 221
#   Min sequence length  : 12
#   Max sequence length  : 97
#   Avg sequence length  : 44.99
#   Median length        : 52.00
#
# Label: doa
#   Number of sequences  : 11
#   Min sequence length  : 53
#   Max sequence length  : 64
#   Avg sequence length  : 56.27
#   Median length        : 54.00
#
# Label: doa_000
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: doa_001
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: doa_002
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: doa_003
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: doa_004
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: doa_005
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: doa_006
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: doa_007
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: doa_008
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: doa_009
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: doa_010
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: d
#   Number of sequences  : 220
#   Min sequence length  : 16
#   Max sequence length  : 103
#   Avg sequence length  : 51.95
#   Median length        : 51.00
#
# Label: e
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 93
#   Avg sequence length  : 49.69
#   Median length        : 54.00
#
# Label: foto
#   Number of sequences  : 11
#   Min sequence length  : 28
#   Max sequence length  : 41
#   Avg sequence length  : 35.00
#   Median length        : 34.00
#
# Label: foto_000
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: foto_001
#   Number of sequences  : 2
#   Min sequence length  : 36
#   Max sequence length  : 36
#   Avg sequence length  : 36.00
#   Median length        : 36.00
#
# Label: foto_002
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: foto_003
#   Number of sequences  : 2
#   Min sequence length  : 34
#   Max sequence length  : 34
#   Avg sequence length  : 34.00
#   Median length        : 34.00
#
# Label: foto_004
#   Number of sequences  : 2
#   Min sequence length  : 28
#   Max sequence length  : 28
#   Avg sequence length  : 28.00
#   Median length        : 28.00
#
# Label: foto_005
#   Number of sequences  : 2
#   Min sequence length  : 38
#   Max sequence length  : 38
#   Avg sequence length  : 38.00
#   Median length        : 38.00
#
# Label: foto_006
#   Number of sequences  : 2
#   Min sequence length  : 31
#   Max sequence length  : 31
#   Avg sequence length  : 31.00
#   Median length        : 31.00
#
# Label: foto_007
#   Number of sequences  : 2
#   Min sequence length  : 34
#   Max sequence length  : 34
#   Avg sequence length  : 34.00
#   Median length        : 34.00
#
# Label: foto_008
#   Number of sequences  : 2
#   Min sequence length  : 41
#   Max sequence length  : 41
#   Avg sequence length  : 41.00
#   Median length        : 41.00
#
# Label: foto_009
#   Number of sequences  : 2
#   Min sequence length  : 33
# ...
#
# Label: teman_003
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: teman_004
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: teman_005
#   Number of sequences  : 2
#   Min sequence length  : 71
#   Max sequence length  : 71
#   Avg sequence length  : 71.00
#   Median length        : 71.00
#
# Label: teman_006
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: teman_007
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: teman_008
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: teman_009
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: teman_010
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: tentang
#   Number of sequences  : 11
#   Min sequence length  : 58
#   Max sequence length  : 73
#   Avg sequence length  : 62.91
#   Median length        : 63.00
#
# Label: tentang_000
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tentang_001
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: tentang_002
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: tentang_003
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tentang_004
#   Number of sequences  : 2
#   Min sequence length  : 73
#   Max sequence length  : 73
#   Avg sequence length  : 73.00
#   Median length        : 73.00
#
# Label: tentang_005
#   Number of sequences  : 2
#   Min sequence length  : 68
#   Max sequence length  : 68
#   Avg sequence length  : 68.00
#   Median length        : 68.00
#
# Label: tentang_006
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: tentang_007
#   Number of sequences  : 2
#   Min sequence length  : 66
#   Max sequence length  : 66
#   Avg sequence length  : 66.00
#   Median length        : 66.00
#
# Label: tentang_008
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: tentang_009
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tentang_010
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: terang
#   Number of sequences  : 12
#   Min sequence length  : 46
#   Max sequence length  : 63
#   Avg sequence length  : 56.83
#   Median length        : 58.50
#
# Label: terang_000
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: terang_001
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: terang_002
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: terang_003
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: terang_004
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: terang_005
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: terang_006
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: terang_007
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: terang_008
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: terang_009
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: terang_010
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: terang_011
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: ter
#   Number of sequences  : 222
#   Min sequence length  : 13
#   Max sequence length  : 86
#   Avg sequence length  : 43.80
#   Median length        : 50.00
#
# Label: ti
#   Number of sequences  : 221
#   Min sequence length  : 14
#   Max sequence length  : 117
#   Avg sequence length  : 46.58
#   Median length        : 51.00
#
# Label: triliun
#   Number of sequences  : 220
#   Min sequence length  : 16
#   Max sequence length  : 85
#   Avg sequence length  : 49.20
#   Median length        : 54.00
#
# Label: tugas
#   Number of sequences  : 12
#   Min sequence length  : 43
#   Max sequence length  : 64
#   Avg sequence length  : 54.75
#   Median length        : 55.00
#
# Label: tugas_000
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: tugas_001
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tugas_002
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: tugas_003
#   Number of sequences  : 2
#   Min sequence length  : 43
#   Max sequence length  : 43
#   Avg sequence length  : 43.00
#   Median length        : 43.00
#
# Label: tugas_004
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: tugas_005
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: tugas_006
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: tugas_007
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: tugas_008
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: tugas_009
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: tugas_010
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tugas_011
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: tulis
#   Number of sequences  : 11
#   Min sequence length  : 49
#   Max sequence length  : 69
#   Avg sequence length  : 59.45
#   Median length        : 58.00
#
# Label: tulis_000
#   Number of sequences  : 2
#   Min sequence length  : 69
#   Max sequence length  : 69
#   Avg sequence length  : 69.00
#   Median length        : 69.00
#
# Label: tulis_001
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tulis_002
#   Number of sequences  : 2
#   Min sequence length  : 68
#   Max sequence length  : 68
#   Avg sequence length  : 68.00
#   Median length        : 68.00
#
# Label: tulis_003
#   Number of sequences  : 2
#   Min sequence length  : 56
#   Max sequence length  : 56
#   Avg sequence length  : 56.00
#   Median length        : 56.00
#
# Label: tulis_004
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tulis_005
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: tulis_006
#   Number of sequences  : 2
#   Min sequence length  : 54
#   Max sequence length  : 54
#   Avg sequence length  : 54.00
#   Median length        : 54.00
#
# Label: tulis_007
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: tulis_008
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: tulis_009
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tulis_010
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: tunjuk
#   Number of sequences  : 12
#   Min sequence length  : 53
#   Max sequence length  : 64
#   Avg sequence length  : 60.67
#   Median length        : 61.00
#
# Label: tunjuk_000
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: tunjuk_001
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: tunjuk_002
#   Number of sequences  : 2
#   Min sequence length  : 59
#   Max sequence length  : 59
#   Avg sequence length  : 59.00
#   Median length        : 59.00
#
# Label: tunjuk_003
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tunjuk_004
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tunjuk_005
#   Number of sequences  : 2
#   Min sequence length  : 58
#   Max sequence length  : 58
#   Avg sequence length  : 58.00
#   Median length        : 58.00
#
# Label: tunjuk_006
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tunjuk_007
#   Number of sequences  : 2
#   Min sequence length  : 63
#   Max sequence length  : 63
#   Avg sequence length  : 63.00
#   Median length        : 63.00
#
# Label: tunjuk_008
#   Number of sequences  : 2
#   Min sequence length  : 64
#   Max sequence length  : 64
#   Avg sequence length  : 64.00
#   Median length        : 64.00
#
# Label: tunjuk_009
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: tunjuk_010
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: tunjuk_011
#   Number of sequences  : 2
#   Min sequence length  : 61
#   Max sequence length  : 61
#   Avg sequence length  : 61.00
#   Median length        : 61.00
#
# Label: t
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 94
#   Avg sequence length  : 49.24
#   Median length        : 56.00
#
# Label: ulat
#   Number of sequences  : 11
#   Min sequence length  : 44
#   Max sequence length  : 53
#   Avg sequence length  : 47.82
#   Median length        : 48.00
#
# Label: ulat_000
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: ulat_001
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: ulat_002
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: ulat_003
#   Number of sequences  : 2
#   Min sequence length  : 53
#   Max sequence length  : 53
#   Avg sequence length  : 53.00
#   Median length        : 53.00
#
# Label: ulat_004
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: ulat_005
#   Number of sequences  : 2
#   Min sequence length  : 44
#   Max sequence length  : 44
#   Avg sequence length  : 44.00
#   Median length        : 44.00
#
# Label: ulat_006
#   Number of sequences  : 2
#   Min sequence length  : 51
#   Max sequence length  : 51
#   Avg sequence length  : 51.00
#   Median length        : 51.00
#
# Label: ulat_007
#   Number of sequences  : 2
#   Min sequence length  : 49
#   Max sequence length  : 49
#   Avg sequence length  : 49.00
#   Median length        : 49.00
#
# Label: ulat_008
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: ulat_009
#   Number of sequences  : 2
#   Min sequence length  : 46
#   Max sequence length  : 46
#   Avg sequence length  : 46.00
#   Median length        : 46.00
#
# Label: ulat_010
#   Number of sequences  : 2
#   Min sequence length  : 48
#   Max sequence length  : 48
#   Avg sequence length  : 48.00
#   Median length        : 48.00
#
# Label: u
#   Number of sequences  : 220
#   Min sequence length  : 13
#   Max sequence length  : 100
#   Avg sequence length  : 48.44
#   Median length        : 56.00
#
# Label: v
#   Number of sequences  : 220
#   Min sequence length  : 10
#   Max sequence length  : 88
#   Avg sequence length  : 46.64
#   Median length        : 54.00
#
# Label: wan
#   Number of sequences  : 220
#   Min sequence length  : 15
#   Max sequence length  : 101
#   Avg sequence length  : 44.42
#   Median length        : 49.00
#
# Label: wati
#   Number of sequences  : 220
#   Min sequence length  : 18
#   Max sequence length  : 99
#   Avg sequence length  : 50.16
#   Median length        : 54.00
#
# Label: w
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 103
#   Avg sequence length  : 47.23
#   Median length        : 53.00
#
# Label: x
#   Number of sequences  : 220
#   Min sequence length  : 8
#   Max sequence length  : 95
#   Avg sequence length  : 47.95
#   Median length        : 56.00
#
# Label: y
#   Number of sequences  : 220
#   Min sequence length  : 11
#   Max sequence length  : 91
#   Avg sequence length  : 46.36
#   Median length        : 54.00
#
# Label: z
#   Number of sequences  : 220
#   Min sequence length  : 18
#   Max sequence length  : 102
#   Avg sequence length  : 56.36
#   Median length        : 63.00
#
# === GLOBAL SEQUENCE LENGTH DISTRIBUTION ===
# Total sequences        : 21711
# Global min length      : 1
# Global max length      : 153
# Global mean length     : 53.06
# Global median length   : 56.00
# 75th percentile (P75)  : 67.00
# 90th percentile (P90)  : 77.00
# 95th percentile (P95)  : 83.00
#
# === SUGGESTED PADDING LENGTH ===
# Suggested padding length (≈P90): 77
#
# You might choose:
#   - 67  (P75)  → more truncation, faster training
#   - 77 (P90)  → balanced
#   - 83 (P95)  → minimal truncation, more padding
#   - 153 (max) → no truncation, lots of padding
